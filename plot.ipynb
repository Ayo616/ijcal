# %%
import matplotlib.pyplot as plt
import seaborn as sns
import csv
import numpy as np
import warnings

# %%
warnings.filterwarnings('ignore')

f = csv.reader(open('./GNNSafe/results/vis_scores/arxiv-gnnsafe_no_prop_no_reg.csv', 'r'))
l = [i for i in f]
pos_num, neg_num = l[0][0].split(' ')
pos_num, neg_num = int(pos_num), int(neg_num)
score = -np.array(l[1:], dtype=np.float).reshape(-1)
print(score)
pos_score1, neg_score1 = score[:pos_num], score[pos_num:]

f = csv.reader(open('./GNNSafe/results/vis_scores/arxiv-gnnsafe_use_prop_no_reg.csv', 'r'))
l = [i for i in f]
pos_num, neg_num = l[0][0].split(' ')
pos_num, neg_num = int(pos_num), int(neg_num)
score = -np.array(l[1:], dtype=np.float).reshape(-1)
print(score)
pos_score2, neg_score2 = score[:pos_num], score[pos_num:]

f = csv.reader(open('./GNNSafe/results/vis_scores/arxiv-gnnsafe_use_prop_use_reg.csv', 'r'))
l = [i for i in f]
pos_num, neg_num = l[0][0].split(' ')
pos_num, neg_num = int(pos_num), int(neg_num)
score = -np.array(l[1:], dtype=np.float).reshape(-1)
print(score)
pos_score3, neg_score3 = score[:pos_num], score[pos_num:]

sns.set(style='white')
fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(18, 3))

# plot vi frequency distribution
sns.distplot(pos_score1, ax=ax[0], hist=False, kde_kws={'fill': True}, kde=True, color='green', label='in-distribution')
ax[0].vlines(np.median(pos_score1), 0, 0.8, color='green', linestyles='dashed')
sns.distplot(neg_score1, ax=ax[0], hist=False, kde_kws={'fill': True}, kde=True, color='red', label='out-of-distribution')
ax[0].vlines(np.median(neg_score1), 0, 0.8, color='red', linestyles='dashed')
ax[0].set_ylim(0,0.8)
ax[0].set_xlim(-15, 0)
ax[0].set_title('GNNSafe w/o energy propagation', size=15)
ax[0].set_xlabel('Energy score', size=15)
ax[0].set_ylabel('Frequency', size=15)
ax[0].legend(loc='upper left', fontsize=15)
# fig.savefig('./figs/arxiv-score-energy.pdf', bbox_inches='tight')

# plot base frequency distribution
sns.distplot(pos_score2, ax=ax[1], hist=False, kde_kws={'fill': True}, color='green', label='in-distribution')
ax[1].vlines(np.median(pos_score2), 0, 1.6, color='green', linestyles='dashed')
sns.distplot(neg_score2, ax=ax[1], hist=False, kde_kws={'fill': True}, color='red', label='out-of-distribution')
ax[1].vlines(np.median(neg_score2), 0, 1.6, color='red', linestyles='dashed')
ax[1].set_ylim(0,1.6)
ax[1].set_xlim(-10, 0)
ax[1].set_title('GNNSafe', size=15)
ax[1].set_xlabel('Energy score', size=15)
ax[1].set_ylabel('Frequency', size=15)
ax[1].legend(loc='upper left', fontsize=15)
# fig.savefig('./figs/arxiv-score-energyprop.pdf', bbox_inches='tight')

# plot 123 frequency distribution
sns.distplot(pos_score3, ax=ax[2], hist=False, kde_kws={'fill': True}, color='green', label='in-distribution')
ax[2].vlines(np.median(pos_score3), 0, 0.8, color='green', linestyles='dashed')
sns.distplot(neg_score3, ax=ax[2], hist=False, kde_kws={'fill': True}, color='red', label='out-of-distribution')
ax[2].vlines(np.median(neg_score3), 0, 0.8, color='red', linestyles='dashed')
ax[2].set_ylim(0,0.8)
ax[2].set_xlim(-10, 0)
ax[2].set_title('GNNSafe++', size=15)
ax[2].set_xlabel('Energy score', size=15)
ax[2].set_ylabel('Frequency', size=15)
ax[2].legend(loc='upper left', fontsize=15)
# fig.savefig('./figs/arxiv-score-energypropreg.pdf', bbox_inches='tight')

fig.tight_layout()
# fig.savefig('./figs/arxiv-score.pdf', bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 3
#       1 warnings.filterwarnings('ignore')
# ----> 3 f = csv.reader(open('./GNNSafe/results/vis_scores/arxiv-gnnsafe_no_prop_no_reg.csv', 'r'))
#       4 l = [i for i in f]
#       5 pos_num, neg_num = l[0][0].split(' ')
#
# File ~/anaconda3/lib/python3.10/site-packages/IPython/core/interactiveshell.py:282, in _modified_open(file, *args, **kwargs)
#     275 if file in {0, 1, 2}:
#     276     raise ValueError(
#     277         f"IPython won't let you open fd={file} by default "
#     278         "as it is likely to crash IPython. If you know what you are doing, "
#     279         "you can use builtins' open."
#     280     )
# --> 282 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: './GNNSafe/results/vis_scores/arxiv-gnnsafe_no_prop_no_reg.csv'

# %%
warnings.filterwarnings('ignore')

f = csv.reader(open('./GNNSafe/results/vis_scores/twitch-gnnsafe_no_prop_no_reg.csv', 'r'))
l = [i for i in f]
pos_num, neg_num = l[0][0].split(' ')
pos_num, neg_num = int(pos_num), int(neg_num)
score = -np.array(l[1:], dtype=np.float).reshape(-1)
print(score)
pos_score1, neg_score1 = score[:pos_num], score[pos_num:]

f = csv.reader(open('./GNNSafe/results/vis_scores/twitch-gnnsafe_use_prop_no_reg.csv', 'r'))
l = [i for i in f]
pos_num, neg_num = l[0][0].split(' ')
pos_num, neg_num = int(pos_num), int(neg_num)
score = -np.array(l[1:], dtype=np.float).reshape(-1)
print(score)
pos_score2, neg_score2 = score[:pos_num], score[pos_num:]

f = csv.reader(open('./GNNSafe/results/vis_scores/twitch-gnnsafe_use_prop_use_reg.csv', 'r'))
l = [i for i in f]
pos_num, neg_num = l[0][0].split(' ')
pos_num, neg_num = int(pos_num), int(neg_num)
score = -np.array(l[1:], dtype=np.float).reshape(-1)
print(score)
pos_score3, neg_score3 = score[:pos_num], score[pos_num:]

sns.set(style='white')
fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(18, 3))

# plot vi frequency distribution
sns.distplot(pos_score1, ax=ax[0], hist=False, kde_kws={'fill': True}, color='green', label='in-distribution')
ax[0].vlines(np.median(pos_score1), 0, 10, color='green', linestyles='dashed')
sns.distplot(neg_score1, ax=ax[0], hist=False, kde_kws={'fill': True}, color='red', label='out-of-distribution')
ax[0].vlines(np.median(neg_score1), 0, 10, color='red', linestyles='dashed')
ax[0].set_ylim(0,10)
ax[0].set_xlim(-1.1, -0.4)
ax[0].set_title('GNNSafe w/o energy propagation', size=15)
ax[0].set_xlabel('Energy score', size=15)
ax[0].set_ylabel('Frequency', size=15)
ax[0].legend(loc='upper left', fontsize=15)

# plot base frequency distribution
sns.distplot(pos_score2, ax=ax[1], hist=False, kde_kws={'fill': True}, color='green', label='in-distribution')
ax[1].vlines(np.median(pos_score2), 0, 10, color='green', linestyles='dashed')
sns.distplot(neg_score2, ax=ax[1], hist=False, kde_kws={'fill': True}, color='red', label='out-of-distribution')
ax[1].vlines(np.median(neg_score2), 0, 10, color='red', linestyles='dashed')
ax[1].set_ylim(0,10)
ax[1].set_xlim(-1.1, -0.4)
ax[1].set_title('GNNSafe', size=15)
ax[1].set_xlabel('Energy score', size=15)
ax[1].set_ylabel('Frequency', size=15)
ax[1].legend(loc='upper left', fontsize=15)

# plot 123 frequency distribution
sns.distplot(pos_score3, ax=ax[2], hist=False, kde_kws={'fill': True}, color='green', label='in-distribution')
ax[2].vlines(np.median(pos_score3), 0, 1, color='green', linestyles='dashed')
sns.distplot(neg_score3, ax=ax[2], hist=False, kde_kws={'fill': True}, color='red', label='out-of-distribution')
ax[2].vlines(np.median(neg_score3), 0, 1, color='red', linestyles='dashed')
ax[2].set_ylim(0,1)
ax[2].set_xlim(-10, 0)
ax[2].set_title('GNNSafe++', size=15)
ax[2].set_xlabel('Energy score', size=15)
ax[2].set_ylabel('Frequency', size=15)
ax[2].legend(loc='upper left', fontsize=15)

fig.tight_layout()
# fig.savefig('./figs/twitch-score.pdf', bbox_inches='tight')

# %%
# different backbones

import matplotlib.pyplot as plt
import seaborn as sns
import csv
import numpy as np

auroc1, aupr1, fpr1 = [], [], []
auroc2, aupr2, fpr2 = [], [], []
auroc3, aupr3, fpr3 = [], [], []

f = csv.reader(open('./GNNSafe/results/discuss/backbone.csv', 'r'))
for i, e in enumerate(f):
    if i % 3 == 1 and i / 3 < 25:
        con = e[0].split(' ')
        a, p, f = float(con[5]), float(con[13]), float(con[21])
        auroc1.append(a)
        aupr1.append(p)
        fpr1.append(f)
    elif i % 3 == 1 and i / 3 < 50:
        con = e[0].split(' ')
        a, p, f = float(con[5]), float(con[13]), float(con[21])
        auroc2.append(a)
        aupr2.append(p)
        fpr2.append(f)
    elif i % 3 == 1 and i / 3 < 75:
        con = e[0].split(' ')
        a, p, f = float(con[5]), float(con[13]), float(con[21])
        auroc3.append(a)
        aupr3.append(p)
        fpr3.append(f)

print(len(auroc1), len(auroc2), len(auroc3))

# cora label

auroc1 = np.array(auroc1).reshape(-1, 5)[:5]
aupr1 = np.array(aupr1).reshape(-1, 5)[:5]
fpr1 = np.array(fpr1).reshape(-1, 5)[:5]
print(auroc1)

# cora feature

auroc2 = np.array(auroc2).reshape(-1, 5)[:5]
aupr2 = np.array(aupr2).reshape(-1, 5)[:5]
fpr2 = np.array(fpr2).reshape(-1, 5)[:5]
print(auroc2)

# cora structure

auroc3 = np.array(auroc3).reshape(-1, 5)[:5]
aupr3 = np.array(aupr3).reshape(-1, 5)[:5]
fpr3 = np.array(fpr3).reshape(-1, 5)[:5]
print(auroc3)

fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(18,3))
sns.set(style='whitegrid')

# color=['#d53e4f','#f46d43','#fdae61','#9970ab','#c2a5cf','#abdda4']
color=['#9970ab','#f46d43','#c2a5cf','#abdda4','#66c2a5']
x_name = ['MLP', 'GCN', 'GAT', 'JKNet', 'MixHop']
x_name = x_name[:5]

width=0.15
xticks = np.arange(5)
ax[0].bar(x=x_name, height=auroc1[:, 0], label='MSP', alpha=1.0, width=width, color=color[1])
ax[0].bar(x=xticks+width, height=auroc1[:, 1], label='Energy', alpha=1.0, width=width, color=color[2])
ax[0].bar(x=xticks+width*2, height=auroc1[:, 2], label='Energy FT', alpha=1.0, width=width, color=color[0])
ax[0].bar(x=xticks+width*3, height=auroc1[:, 3], label='GNNSafe', alpha=1.0, width=width, color=color[3])
ax[0].bar(x=xticks+width*4, height=auroc1[:, 4], label='GNNSafe++', alpha=1.0, width=width, color=color[4])
ax[0].set_xticks(xticks + 0.3)
ax[0].set_ylabel('AUROC', size=15)
ax[0].set_ylim([40, 100])
ax[0].set_title('Structure', size=15)
ax[0].tick_params(labelsize=15)

ax[1].bar(x=x_name, height=auroc2[:, 0], alpha=1.0, width=width, color=color[1])
ax[1].bar(x=xticks+width, height=auroc2[:, 1], alpha=1.0, width=width, color=color[2])
ax[1].bar(x=xticks+width*2, height=auroc2[:, 2], alpha=1.0, width=width, color=color[0])
ax[1].bar(x=xticks+width*3, height=auroc2[:, 3], alpha=1.0, width=width, color=color[3])
ax[1].bar(x=xticks+width*4, height=auroc2[:, 4], alpha=1.0, width=width, color=color[4])
ax[1].set_xticks(xticks + 0.3)
ax[1].set_ylabel('AUROC', size=15)
ax[1].set_ylim([40, 100])
ax[1].set_title('Feature', size=15)
ax[1].tick_params(labelsize=15)

ax[2].bar(x=x_name, height=auroc3[:, 0], alpha=1.0, width=width, color=color[1])
ax[2].bar(x=xticks+width, height=auroc3[:, 1], alpha=1.0, width=width, color=color[2])
ax[2].bar(x=xticks+width*2, height=auroc3[:, 2], alpha=1.0, width=width, color=color[0])
ax[2].bar(x=xticks+width*3, height=auroc3[:, 3], alpha=1.0, width=width, color=color[3])
ax[2].bar(x=xticks+width*4, height=auroc3[:, 4], alpha=1.0, width=width, color=color[4])
ax[2].set_xticks(xticks + 0.3)
ax[2].set_ylabel('AUROC', size=15)
ax[2].set_ylim([40, 100])
ax[2].set_title('Label', size=15)
ax[2].tick_params(labelsize=15)

fig.legend(loc='lower center', bbox_to_anchor=(0.5,0.95), fancybox=True, fontsize=15, ncol=5)
plt.tight_layout()
plt.show()
# fig.savefig('./figs/backbone.pdf', bbox_inches='tight')

# %%
# propagation layers and strength
import csv
import numpy as np

auroc1, aupr1, fpr1 = [], [], []

f = csv.reader(open('./GNNSafe/results/discuss/prop.csv', 'r'))
for i, e in enumerate(f):
    if i % 3 == 1 and i / 3 < 55:
        con = e[0].split(' ')
        a, p, f = float(con[5]), float(con[13]), float(con[21])
        auroc1.append(a)
        aupr1.append(p)
        fpr1.append(f)

print(len(auroc1))

auroc1 = np.array(auroc1).reshape(-1, 11)
aupr1 = np.array(aupr1).reshape(-1, 11)
fpr1 = np.array(fpr1).reshape(-1, 11)
print(auroc1)

x = range(0, 11)
x_real = [1, 2, 3, 5, 8, 12, 16, 24, 36, 48, 64]

fig = plt.figure(figsize=(6,3))
sns.set(style='whitegrid')
plt.plot(x, auroc1[0],color='#9970ab',marker='o', linewidth=2.0,ms=5.0, label='$\\alpha$=0.1')
plt.plot(x, auroc1[1],color='#f46d43',marker='o', linewidth=2.0,ms=5.0, label='$\\alpha$=0.3')
plt.plot(x, auroc1[2],color='#c2a5cf',marker='o', linewidth=2.0,ms=5.0, label='$\\alpha$=0.5')
plt.plot(x, auroc1[3],color='#abdda4',marker='o', linewidth=2.0,ms=5.0, label='$\\alpha$=0.7')
plt.plot(x, auroc1[4],color='#66c2a5',marker='o', linewidth=2.0,ms=5.0, label='$\\alpha$=0.9')
plt.ylabel('AUROC', size=15)
plt.xlabel('Depth $K$', size=15)
plt.grid(linestyle='--')
plt.tick_params(labelsize=15)
plt.xticks(x, x_real)
# plt.title('Cora', size=15)
plt.legend(loc='lower left', fontsize=14, ncol=3)

plt.tight_layout()
# fig.savefig('./figs/propagation.pdf', bbox_inches='tight')
            
plt.show()

# %%
# margin hyper-parameters
import csv
import numpy as np

auroc1, aupr1, fpr1 = [], [], []

f = csv.reader(open('./GNNSafe/results/discuss/margin.csv', 'r'))
for i, e in enumerate(f):
    if i % 3 == 1 and i / 3 < 24:
        con = e[0].split(' ')
        a, p, f = float(con[5]), float(con[13]), float(con[21])
        auroc1.append(a)
        aupr1.append(p)
        fpr1.append(f)

print(len(auroc1))

auroc1 = np.array(auroc1).reshape(-1, 8)
aupr1 = np.array(aupr1).reshape(-1, 8)
fpr1 = np.array(fpr1).reshape(-1, 8)
print(auroc1)

x = range(0, 8)
x_real = [10, 5, 2, 0, -1, -2, -3, -4]

fig = plt.figure(figsize=(6,3))
sns.set(style='whitegrid')
plt.plot(x, auroc1[0],color='#9970ab',marker='o', linewidth=2.0,ms=5.0, label='$t_{out}$=-9')
plt.plot(x, auroc1[1],color='#f46d43',marker='o', linewidth=2.0,ms=5.0, label='$t_{out}$=-7')
plt.plot(x, auroc1[2],color='#c2a5cf',marker='o', linewidth=2.0,ms=5.0, label='$t_{out}$=-5')
plt.ylabel('AUROC', size=15)
plt.xlabel('$t_{in}$', size=15)
plt.grid(linestyle='--')
plt.tick_params(labelsize=15)
plt.xticks(x, x_real)
# plt.title('Structure', size=15)
plt.legend(loc='lower left', fontsize=14, ncol=3)

plt.tight_layout()
# fig.savefig('./figs/margin.pdf', bbox_inches='tight')

plt.show()

# %%
# lamda
import csv
import numpy as np

auroc1, aupr1, fpr1 = [], [], []

f = csv.reader(open('./GNNSafe/results/discuss/lamda.csv', 'r'))
for i, e in enumerate(f):
    if i % 3 == 1 and i / 3 < 7:
        con = e[0].split(' ')
        a, p, f = float(con[5]), float(con[13]), float(con[21])
        auroc1.append(a)
        aupr1.append(p)
        fpr1.append(f)

print(len(auroc1))

auroc1 = np.array(auroc1)
aupr1 = np.array(aupr1)
fpr1 = np.array(fpr1)
print(auroc1)

x = range(0, 7)
x_real = [0.001,0.005,0.01,0.05,0.1,0.5,1.0]

fig = plt.figure(figsize=(6,3))
sns.set(style='whitegrid')
plt.plot(x, auroc1,color='#9970ab',marker='o', linewidth=2.0,ms=5.0)
plt.ylabel('AUROC', size=15)
plt.xlabel('$\\lambda$', size=15)
plt.grid(linestyle='--')
plt.tick_params(labelsize=15)
plt.tick_params(labelsize=15)

plt.tight_layout()
# fig.savefig('./figs/lambda.pdf', bbox_inches='tight')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv('./GNNSafe/results/myresult/ind_score_averg.csv')
data_ood = pd.read_csv('./GNNSafe/results/myresult/ood_score_averg.csv')
# 设置颜色代码
color1 = "#038355" # 孔雀绿
color2 = "#ffc34e" # 向日黄

data.plot()
data_ood.plot()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv('./GNNSafe/results/mytest2.csv')
# 设置颜色代码
color1 = "#038355" # 孔雀绿
color2 = "#ffc34e" # 向日黄

data.plot()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv('./GNNSafe/results/mytest2.csv')
# 设置颜色代码
color1 = "#038355" # 孔雀绿
color2 = "#ffc34e" # 向日黄

data.plot()
# gcn

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv('./GNNSafe/results/maxmin_mytest2.csv')
# 设置颜色代码
color1 = "#038355" # 孔雀绿
color2 = "#ffc34e" # 向日黄

data.plot.area(stacked=False)

data1 = pd.read_csv('./GNNSafe/results/averg_mytest2.csv')
data1.plot()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv('./GNNSafe/results/mytest2.csv')
# 设置颜色代码
color1 = "#038355" # 孔雀绿
color2 = "#ffc34e" # 向日黄

data.plot()
# mlp

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv('./GNNSafe/results/mytest2.csv')


ax = data.plot.scatter(x="ind_max", y="ind_min", color="DarkBlue", label="Group 1")
data.plot.scatter(x="ood_max", y="ood_min", color="DarkGreen", label="Group 2", ax=ax)

# %%
fig,axes = plt.subplots(2,2,figsize=(12,6))  # 不管是否填充子图区域，一次性将所有子图Axes构建完成

ax1 = axes[0,0]
ax1.scatter(data.iloc[0:100,0],data.iloc[0:100,1])
ax1.scatter(data.iloc[0:100,2],data.iloc[0:100,3])

ax2 = axes[0,1]
ax2.scatter(data.iloc[100:200,0],data.iloc[100:200,1])
ax2.scatter(data.iloc[100:200,2],data.iloc[100:200,3])

ax3 = axes[1,0]
ax3.plot(data.iloc[200:300,0],data.iloc[200:300,1])
ax3.plot(data.iloc[200:300,2],data.iloc[200:300,3])

ax4 = axes[1,1]
ax4.plot(data.iloc[300:400,0],data.iloc[300:400,1])
ax4.plot(data.iloc[300:400,2],data.iloc[300:400,3])

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv('./GNNSafe/results/mytest2.csv')
# 设置颜色代码
color1 = "#038355" # 孔雀绿
color2 = "#ffc34e" # 向日黄

data.plot()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv('./GNNSafe/results/mytest2.csv')
# 设置颜色代码
color1 = "#038355" # 孔雀绿
color2 = "#ffc34e" # 向日黄

data.plot()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv('./GNNSafe/results/myresults/randomNodeEnerge.csv')
# data = data.iloc[:, [0,2,4,6,8,10]]
# 设置颜色代码
color1 = "#038355" # 孔雀绿
color2 = "#ffc34e" # 向日黄


fig = plt.figure(figsize=(8,8),dpi=100)
plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=None, hspace=0.8)#调整子图间距


axes = fig.subplots(nrows=2, ncols=1)
ax1, ax2 = axes.ravel()
ax1.tick_params(labelsize=15)
ax2.tick_params(labelsize=15)


ax = data.iloc[:, [1,3,5,7,9]].plot(title="OOD",ax=ax2,grid=False)
ax.set_ylabel("ENERGY SCORE",size=17)
ax.set_xlabel("EPOCHS",size=17)
ax.set_title("OOD",fontsize=17)
# ax.legend().remove()
ax.legend(bbox_to_anchor=(0.5, -0.65),loc='lower center',ncol=3,fontsize=13)
sns.set(style='white')




ax = data.iloc[:, [0,2,4,6,8,10]].plot(title="IND",ax=ax1,grid=False)
ax.set_ylabel("ENERGY SCORE",size=17)
ax.set_xlabel("EPOCHS",size=17)
ax.set_title("IND",fontsize=17)
# ax.legend().remove()
ax.legend(bbox_to_anchor=(0.5, -0.65),loc='lower center',ncol=3,fontsize=13)
sns.set(style='white')


fig.savefig('./figs/random-score.pdf', bbox_inches='tight')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv('./GNNSafe/results/myresult/ind_score_averg.csv')
data_ood = pd.read_csv('./GNNSafe/results/myresult/ood_score_averg.csv')
av_data = pd.read_csv('./GNNSafe/results/myresult/ind_ood_score_averg.csv')

av_data_maxmin = pd.read_csv('./GNNSafe/results/maxmin_mytest2.csv')

# 设置颜色代码
color1 = "#038355" # 孔雀绿
color2 = "#ffc34e" # 向日黄

fig = plt.figure(figsize=(18,8),dpi=100)
plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=None, hspace=0.4)#调整子图间距

axes = fig.subplots(nrows=2, ncols=2)
ax1, ax2,ax3, ax4 = axes.ravel()
ax1.tick_params(labelsize=15)
ax2.tick_params(labelsize=15)
ax3.tick_params(labelsize=15)
ax4.tick_params(labelsize=15)

ax = data.plot(title="IND",ax=ax1,grid=False,linewidth=2.5)
ax.set_title("IND",fontsize=17)
ax.set_xlabel("EPOCHS",size=17)
ax.set_ylabel("ENERGY SCORE",size=17)

ax = data_ood.plot(title="OOD",ax=ax2,grid=False,linewidth=2.5)
ax.set_title("OOD",fontsize=17)
ax.set_xlabel("EPOCHS",size=17)
ax.set_ylabel("ENERGY SCORE",size=17)


ax = av_data.plot(title="ind_ood_score_averg",ax=ax3,grid=False,linewidth=2)
ax.set_title("IND_OOD_SCORE_AVERAGE",fontsize=17)
ax.set_xlabel("EPOCHS",size=17)
ax.set_ylabel("ENERGY SCORE",size=17)

ax = av_data_maxmin.plot.area(title="av",ax=ax4,grid=False,stacked=False,linewidth=1)
ax.legend(loc='lower right',ncol=2,fontsize=13,)
ax.set_ylabel("ENERGY SCORE",size=17)
ax.set_xlabel("EPOCHS",size=17)
ax.set_title("IND_OOD_SCORE_MAX_MIN",fontsize=17)

# %% [markdown]
# ### 减少参数，增加epoch
# 由上述实验可是看出，在足够的epoch下，OOD和IND的能量分数会进行明显的分化，所以不需要设定额外的参数。可以对原文进行一个参数缩减。此外，我们可以看出在epoch足够的情况下，OOD的能量分数偏移量是大于IND的能量分数，在图上表示为OOD的能量上下限包含了IND的能量分数，所以如果要进一步提升模型能力，必须有效地区分OOD能量分数中所在的IND的能量分数范围中的个例。

# %% [markdown]
# ### 增加OOD损失函数
# 将OOD数据用于图网络训练中，与IND真实标签形成新的OOD误差，将此误差加到综合误差之中，用于模型反馈更新。目的是让增加模型的抗OOD能力，在识别OOD数据能力的同时，保持IND数据内的分类能力。

# %% [markdown]
# ### 改进检测模式
# 改进能量分数用于在图网络中OOD和IND的检测，增加新的指标和依据。因为能量分数处于一维数据，使得OOD和IND的能量分数范围存在了重合部分，模型的泛化能力没有得到有效提高

# %% [markdown]
# ## 分析过程
# Detect OOD 依据的就是能量分数的之间的差异，而且是一维数据能量分数的划分。所以与图神经网络的训练是脱轨的，即是说，能量分数的计算输入，是已经训练好的图神经网络的输出层，属于静态图神经网络的输出。换句话说，能量分数并没有参与图神经网络的训练，在原文中虽然将能量分数的误差当作综合误差之一，但是我们已经论证了减少了这个参数，增加足够的epoch下，仍然能够起到作用，所以原文中的能量分数，没有实质参与图神经网络中的训练。
# * 如何能够改进检测模式，最好的一体式方法，是将图神经网络的某些部分与能量函数关联起来，赋予能量函数具有训练的特性。

# %%
warnings.filterwarnings('ignore')

f = csv.reader(open('./GNNSafe/results/vis_scores/arxiv_Model.csv', 'r'))
l = [i for i in f]
pos_num, neg_num = l[0][0].split(' ')
pos_num, neg_num = int(pos_num), int(neg_num)
score = -np.array(l[1:], dtype=np.float).reshape(-1)

pos_score1, neg_score1 = score[:pos_num], score[pos_num:]
print(pos_score1)
f = csv.reader(open('./GNNSafe/results/vis_scores/arxiv_Model_slayer.csv', 'r'))
l = [i for i in f]
pos_num, neg_num = l[0][0].split(' ')
pos_num, neg_num = int(pos_num), int(neg_num)
score = -np.array(l[1:], dtype=np.float).reshape(-1)
pos_score2, neg_score2 = score[:pos_num], score[pos_num:]


f = csv.reader(open('./GNNSafe/results/vis_scores/arxiv_Model_mlayer.csv', 'r'))
l = [i for i in f]
pos_num, neg_num = l[0][0].split(' ')
pos_num, neg_num = int(pos_num), int(neg_num)
score = -np.array(l[1:], dtype=np.float).reshape(-1)
pos_score3, neg_score3 = score[:pos_num], score[pos_num:]

f = csv.reader(open('./GNNSafe/results/vis_scores/arxiv_Model_Final.csv', 'r'))
l = [i for i in f]
pos_num, neg_num = l[0][0].split(' ')
pos_num, neg_num = int(pos_num), int(neg_num)
score = -np.array(l[1:], dtype=np.float).reshape(-1)
pos_score4, neg_score4 = score[:pos_num], score[pos_num:]

sns.set(style='white')
fig, ax = plt.subplots(nrows=1, ncols=4, figsize=(30, 4))

# plot vi frequency distribution
sns.distplot(pos_score1, ax=ax[0], hist=False, kde_kws={'fill': True}, kde=True, color='green', label='in-distribution')
ax[0].vlines(np.median(pos_score1), 0, 10, color='green', linestyles='dashed')
sns.distplot(neg_score1, ax=ax[0], hist=False, kde_kws={'fill': True}, kde=True, color='blue', label='out-of-distribution')
ax[0].vlines(np.median(neg_score1), 0, 10, color='red', linestyles='dashed')
ax[0].set_ylim(0,2)
ax[0].set_xlim(-8, -3)
ax[0].set_title('GCN', size=15)
ax[0].set_xlabel('Energy score', size=15)
ax[0].set_ylabel('Frequency', size=15)
ax[0].legend(loc='upper left', fontsize=15)
# fig.savefig('./figs/arxiv-score-energy.pdf', bbox_inches='tight')

# plot base frequency distribution
sns.distplot(pos_score2, ax=ax[1], hist=False, kde_kws={'fill': True}, color='green', label='in-distribution')
ax[1].vlines(np.median(pos_score2), 0, 10, color='green', linestyles='dashed')
sns.distplot(neg_score2, ax=ax[1], hist=False, kde_kws={'fill': True}, color='blue', label='out-of-distribution')
ax[1].vlines(np.median(neg_score2), 0, 10, color='red', linestyles='dashed')
ax[1].set_ylim(0,2)
ax[1].set_xlim(-8, 1)
ax[1].set_title('S-Layer', size=15)
ax[1].set_xlabel('Energy score', size=15)
ax[1].set_ylabel('Frequency', size=15)
ax[1].legend(loc='upper left', fontsize=15)
# fig.savefig('./figs/arxiv-score-energyprop.pdf', bbox_inches='tight')

# plot 123 frequency distribution
sns.distplot(pos_score3, ax=ax[2], hist=False, kde_kws={'fill': True}, color='green', label='in-distribution')
ax[2].vlines(np.median(pos_score3), 0, 10, color='green', linestyles='dashed')
sns.distplot(neg_score3, ax=ax[2], hist=False, kde_kws={'fill': True}, color='blue', label='out-of-distribution')
ax[2].vlines(np.median(neg_score3), 0, 10, color='red', linestyles='dashed')
ax[2].set_ylim(0,2)
ax[2].set_xlim(-10.1, -3)
ax[2].set_title('M-Layer', size=15)
ax[2].set_xlabel('Energy score', size=15)
ax[2].set_ylabel('Frequency', size=15)
ax[2].legend(loc='upper left', fontsize=15)
# fig.savefig('./figs/arxiv-score-energypropreg.pdf', bbox_inches='tight')

# plot 123 frequency distribution
sns.distplot(pos_score4, ax=ax[3], hist=False, kde_kws={'fill': True}, color='green', label='in-distribution')
ax[3].vlines(np.median(pos_score4), 0, 7, color='green', linestyles='dashed')
sns.distplot(neg_score4, ax=ax[3], hist=False, kde_kws={'fill': True}, color='blue', label='out-of-distribution')
ax[3].vlines(np.median(neg_score4), 0, 7, color='red', linestyles='dashed')
ax[3].set_ylim(0,2)
ax[3].set_xlim(-10.1, -0.1)
ax[3].set_title('GEVN', size=15)
ax[3].set_xlabel('Energy score', size=15)
ax[3].set_ylabel('Frequency', size=15)
ax[3].legend(loc='upper left', fontsize=15)

fig.tight_layout()
fig.savefig('./figs/arxiv-score.pdf', bbox_inches='tight')

# %%
warnings.filterwarnings('ignore')

f = csv.reader(open('./GNNSafe/results/vis_scores/twitch_Model.csv', 'r'))
l = [i for i in f]
pos_num, neg_num = l[0][0].split(' ')
pos_num, neg_num = int(pos_num), int(neg_num)
score = -np.array(l[1:], dtype=np.float).reshape(-1)

pos_score1, neg_score1 = score[:pos_num], score[pos_num:]
print(pos_score1)
f = csv.reader(open('./GNNSafe/results/vis_scores/twitch_Model_slayer.csv', 'r'))
l = [i for i in f]
pos_num, neg_num = l[0][0].split(' ')
pos_num, neg_num = int(pos_num), int(neg_num)
score = -np.array(l[1:], dtype=np.float).reshape(-1)
pos_score2, neg_score2 = score[:pos_num], score[pos_num:]


f = csv.reader(open('./GNNSafe/results/vis_scores/twitch_Model_mlayer.csv', 'r'))
l = [i for i in f]
pos_num, neg_num = l[0][0].split(' ')
pos_num, neg_num = int(pos_num), int(neg_num)
score = -np.array(l[1:], dtype=np.float).reshape(-1)
pos_score3, neg_score3 = score[:pos_num], score[pos_num:]

f = csv.reader(open('./GNNSafe/results/vis_scores/twitch_Model_Final.csv', 'r'))
l = [i for i in f]
pos_num, neg_num = l[0][0].split(' ')
pos_num, neg_num = int(pos_num), int(neg_num)
score = -np.array(l[1:], dtype=np.float).reshape(-1)
pos_score4, neg_score4 = score[:pos_num], score[pos_num:]

sns.set(style='white')
fig, ax = plt.subplots(nrows=1, ncols=4, figsize=(30, 4))

# plot vi frequency distribution
sns.distplot(pos_score1, ax=ax[0], hist=False, kde_kws={'fill': True}, kde=True, color='green', label='in-distribution')
ax[0].vlines(np.median(pos_score1), 0, 10, color='green', linestyles='dashed')
sns.distplot(neg_score1, ax=ax[0], hist=False, kde_kws={'fill': True}, kde=True, color='blue', label='out-of-distribution')
ax[0].vlines(np.median(neg_score1), 0, 10, color='red', linestyles='dashed')
ax[0].set_ylim(0,10)
ax[0].set_xlim(-1, -0.5)
ax[0].set_title('GCN', size=15)
ax[0].set_xlabel('Energy score', size=15)
ax[0].set_ylabel('Frequency', size=15)
ax[0].legend(loc='upper left', fontsize=15)
# fig.savefig('./figs/arxiv-score-energy.pdf', bbox_inches='tight')

# plot base frequency distribution
sns.distplot(pos_score2, ax=ax[1], hist=False, kde_kws={'fill': True}, color='green', label='in-distribution')
ax[1].vlines(np.median(pos_score2), 0, 10, color='green', linestyles='dashed')
sns.distplot(neg_score2, ax=ax[1], hist=False, kde_kws={'fill': True}, color='blue', label='out-of-distribution')
ax[1].vlines(np.median(neg_score2), 0, 10, color='red', linestyles='dashed')
ax[1].set_ylim(0,4)
ax[1].set_xlim(-2, -0.5)
ax[1].set_title('S-Layer', size=15)
ax[1].set_xlabel('Energy score', size=15)
ax[1].set_ylabel('Frequency', size=15)
ax[1].legend(loc='upper left', fontsize=15)
# fig.savefig('./figs/arxiv-score-energyprop.pdf', bbox_inches='tight')

# plot 123 frequency distribution
sns.distplot(pos_score3, ax=ax[2], hist=False, kde_kws={'fill': True}, color='green', label='in-distribution')
ax[2].vlines(np.median(pos_score3), 0, 10, color='green', linestyles='dashed')
sns.distplot(neg_score3, ax=ax[2], hist=False, kde_kws={'fill': True}, color='blue', label='out-of-distribution')
ax[2].vlines(np.median(neg_score3), 0, 10, color='red', linestyles='dashed')
ax[2].set_ylim(0,6)
ax[2].set_xlim(-1.5, 0)
ax[2].set_title('M-Layer', size=15)
ax[2].set_xlabel('Energy score', size=15)
ax[2].set_ylabel('Frequency', size=15)
ax[2].legend(loc='upper left', fontsize=15)
# fig.savefig('./figs/arxiv-score-energypropreg.pdf', bbox_inches='tight')

# plot 123 frequency distribution
sns.distplot(pos_score4, ax=ax[3], hist=False, kde_kws={'fill': True}, color='green', label='in-distribution')
ax[3].vlines(np.median(pos_score4), 0, 7, color='green', linestyles='dashed')
sns.distplot(neg_score4, ax=ax[3], hist=False, kde_kws={'fill': True}, color='blue', label='out-of-distribution')
ax[3].vlines(np.median(neg_score4), 0, 7, color='red', linestyles='dashed')
ax[3].set_ylim(0,7)
ax[3].set_xlim(-1, -0.1)
ax[3].set_title('GEVN', size=15)
ax[3].set_xlabel('Energy score', size=15)
ax[3].set_ylabel('Frequency', size=15)
ax[3].legend(loc='upper left', fontsize=15)

fig.tight_layout()
# fig.savefig('./figs/arxiv-score.pdf', bbox_inches='tight')
fig.savefig('./figs/twitch-score.pdf', bbox_inches='tight')

# %%
warnings.filterwarnings('ignore')

f = csv.reader(open('./GNNSafe/results/vis_scores_o/twitch-gnnsafe_no_prop_no_reg.csv', 'r'))
l = [i for i in f]
pos_num, neg_num = l[0][0].split(' ')
pos_num, neg_num = int(pos_num), int(neg_num)
score = -np.array(l[1:], dtype=np.float).reshape(-1)
print(score)
pos_score1, neg_score1 = score[:pos_num], score[pos_num:]

f = csv.reader(open('./GNNSafe/results/vis_scores_o/twitch-gnnsafe_use_prop_no_reg.csv', 'r'))
l = [i for i in f]
pos_num, neg_num = l[0][0].split(' ')
pos_num, neg_num = int(pos_num), int(neg_num)
score = -np.array(l[1:], dtype=np.float).reshape(-1)
pos_score2, neg_score2 = score[:pos_num], score[pos_num:]

f = csv.reader(open('./GNNSafe/results/vis_scores_o/twitch-gnnsafe_use_prop_use_reg.csv', 'r'))
l = [i for i in f]
pos_num, neg_num = l[0][0].split(' ')
pos_num, neg_num = int(pos_num), int(neg_num)
score = -np.array(l[1:], dtype=np.float).reshape(-1)
pos_score3, neg_score3 = score[:pos_num], score[pos_num:]

sns.set(style='white')
fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(18, 3))

# plot vi frequency distribution
sns.distplot(pos_score1, ax=ax[0], hist=False, kde_kws={'fill': True}, color='green', label='in-distribution')
ax[0].vlines(np.median(pos_score1), 0, 10, color='green', linestyles='dashed')
sns.distplot(neg_score1, ax=ax[0], hist=False, kde_kws={'fill': True}, color='blue', label='out-of-distribution')
ax[0].vlines(np.median(neg_score1), 0, 10, color='red', linestyles='dashed')
ax[0].set_ylim(0,10)
ax[0].set_xlim(-1.1, -0.4)
ax[0].set_title('GNNSafe w/o energy propagation', size=15)
ax[0].set_xlabel('Energy score', size=15)
ax[0].set_ylabel('Frequency', size=15)
ax[0].legend(loc='upper left', fontsize=15)

# plot base frequency distribution
sns.distplot(pos_score2, ax=ax[1], hist=False, kde_kws={'fill': True}, color='green', label='in-distribution')
ax[1].vlines(np.median(pos_score2), 0, 10, color='green', linestyles='dashed')
sns.distplot(neg_score2, ax=ax[1], hist=False, kde_kws={'fill': True}, color='blue', label='out-of-distribution')
ax[1].vlines(np.median(neg_score2), 0, 10, color='red', linestyles='dashed')
ax[1].set_ylim(0,10)
ax[1].set_xlim(-1.1, -0.4)
ax[1].set_title('GNNSafe', size=15)
ax[1].set_xlabel('Energy score', size=15)
ax[1].set_ylabel('Frequency', size=15)
ax[1].legend(loc='upper left', fontsize=15)

# plot 123 frequency distribution
sns.distplot(pos_score3, ax=ax[2], hist=False, kde_kws={'fill': True}, color='green', label='in-distribution')
ax[2].vlines(np.median(pos_score3), 0, 1, color='green', linestyles='dashed')
sns.distplot(neg_score3, ax=ax[2], hist=False, kde_kws={'fill': True}, color='blue', label='out-of-distribution')
ax[2].vlines(np.median(neg_score3), 0, 1, color='red', linestyles='dashed')
ax[2].set_ylim(0,1)
ax[2].set_xlim(-10, 0)
ax[2].set_title('GNNSafe++', size=15)
ax[2].set_xlabel('Energy score', size=15)
ax[2].set_ylabel('Frequency', size=15)
ax[2].legend(loc='upper left', fontsize=15)

fig.tight_layout()
# fig.savefig('./figs/arxiv-score.pdf', bbox_inches='tight')

# %%
# different backbones

import matplotlib.pyplot as plt
import seaborn as sns
import csv
import numpy as np

auroc1, aupr1, fpr1 = [], [], []
auroc2, aupr2, fpr2 = [], [], []
auroc3, aupr3, fpr3 = [], [], []

f = csv.reader(open('./GNNSafe/results/discuss/backbone.csv', 'r'))
for i, e in enumerate(f):
    if i % 3 == 1 and i / 3 < 25:
        con = e[0].split(' ')
        a, p, f = float(con[5]), float(con[13]), float(con[21])
        auroc1.append(a)
        aupr1.append(p)
        fpr1.append(f)
    elif i % 3 == 1 and i / 3 < 50:
        con = e[0].split(' ')
        a, p, f = float(con[5]), float(con[13]), float(con[21])
        auroc2.append(a)
        aupr2.append(p)
        fpr2.append(f)
    elif i % 3 == 1 and i / 3 < 75:
        con = e[0].split(' ')
        a, p, f = float(con[5]), float(con[13]), float(con[21])
        auroc3.append(a)
        aupr3.append(p)
        fpr3.append(f)

print(len(auroc1), len(auroc2), len(auroc3))

# cora label

auroc1 = np.array(auroc1).reshape(-1, 5)[:5]
aupr1 = np.array(aupr1).reshape(-1, 5)[:5]
fpr1 = np.array(fpr1).reshape(-1, 5)[:5]
print(auroc1)

# cora feature

auroc2 = np.array(auroc2).reshape(-1, 5)[:5]
aupr2 = np.array(aupr2).reshape(-1, 5)[:5]
fpr2 = np.array(fpr2).reshape(-1, 5)[:5]
print(auroc2)

# cora structure

auroc3 = np.array(auroc3).reshape(-1, 5)[:5]
aupr3 = np.array(aupr3).reshape(-1, 5)[:5]
fpr3 = np.array(fpr3).reshape(-1, 5)[:5]
print(auroc3)

fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(18,3))
sns.set(style='whitegrid')

color=['#d53e4f','#9c9de2','#f46d43','#a4c7dd','#5152cd','#abdda4']
# color=['#9970ab','#f46d43','#c2a5cf','#abdda4','#66c2a5']
x_name = ['MLP', 'GCN', 'GAT', 'JKNet', 'MixHop']
x_name = x_name[:5]

width=0.15
xticks = np.arange(5)
ax[0].bar(x=x_name, height=auroc1[:, 0], label='MSP', alpha=1.0, width=width, color=color[1])
ax[0].bar(x=xticks+width, height=auroc1[:, 1], label='Energy', alpha=1.0, width=width, color=color[2])
ax[0].bar(x=xticks+width*2, height=auroc1[:, 2], label='GEVN(M-Layer)', alpha=1.0, width=width, color=color[0])
ax[0].bar(x=xticks+width*3, height=auroc1[:, 3], label='GEVN(S-Layer)', alpha=1.0, width=width, color=color[3])
ax[0].bar(x=xticks+width*4, height=auroc1[:, 4], label='GEVN', alpha=1.0, width=width, color=color[4])
ax[0].set_xticks(xticks + 0.3)
ax[0].set_ylabel('AUROC', size=15)
ax[0].set_ylim([40, 100])
ax[0].set_title('Structure', size=15)
ax[0].tick_params(labelsize=15)

ax[1].bar(x=x_name, height=auroc2[:, 0], alpha=1.0, width=width, color=color[1])
ax[1].bar(x=xticks+width, height=auroc2[:, 1], alpha=1.0, width=width, color=color[2])
ax[1].bar(x=xticks+width*2, height=auroc2[:, 2], alpha=1.0, width=width, color=color[0])
ax[1].bar(x=xticks+width*3, height=auroc2[:, 3], alpha=1.0, width=width, color=color[3])
ax[1].bar(x=xticks+width*4, height=auroc2[:, 4], alpha=1.0, width=width, color=color[4])
ax[1].set_xticks(xticks + 0.3)
ax[1].set_ylabel('AUROC', size=15)
ax[1].set_ylim([40, 100])
ax[1].set_title('Feature', size=15)
ax[1].tick_params(labelsize=15)

ax[2].bar(x=x_name, height=auroc3[:, 0], alpha=1.0, width=width, color=color[1])
ax[2].bar(x=xticks+width, height=auroc3[:, 1], alpha=1.0, width=width, color=color[2])
ax[2].bar(x=xticks+width*2, height=auroc3[:, 2], alpha=1.0, width=width, color=color[0])
ax[2].bar(x=xticks+width*3, height=auroc3[:, 3], alpha=1.0, width=width, color=color[3])
ax[2].bar(x=xticks+width*4, height=auroc3[:, 4], alpha=1.0, width=width, color=color[4])
ax[2].set_xticks(xticks + 0.3)
ax[2].set_ylabel('AUROC', size=15)
ax[2].set_ylim([40, 100])
ax[2].set_title('Label', size=15)
ax[2].tick_params(labelsize=15)

fig.legend(loc='lower center', bbox_to_anchor=(0.5,0.95), fancybox=True, fontsize=15, ncol=5)
plt.tight_layout()
plt.show()
fig.savefig('./figs/backbone.pdf', bbox_inches='tight')

# %%
import pandas as pd
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(18,8),dpi=100)
plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=0.3, hspace=0.4)#调整子图间距

axes = fig.subplots(nrows=2, ncols=3)
ax1, ax2,ax3, ax4,ax5, ax6 = axes.ravel()


df = pd.read_csv('./GNNSafe/results/myresults/detect_In_Out_max_min.csv')
# patch_artist=True
# boxprops = {'color': 'blue','facecolor':'b'}
boxprops = {'color': 'blue'}

capprops = {'color': 'red', 'linewidth': '1.5'}
# 创建一个包含每一行为箱线图数据的DataFrame
# df = pd.DataFrame({
#     'Min': [0, 2, 3, 4, 1,1],
#     'Q1': [12, 14, 16, 18, 100,12],
#     'Median': [24, 26, 28, 30, 32,23],
#     'Q3': [36, 38, 40, 42, 44,123],
#     'Max': [48, 50, 52, 54, 56,55]
# })
# print(df.T.shape)
# 绘制每一行数据的箱线图
# np.r_[1:3, 15, 17, 50:52] 指定行数
ax1.boxplot(df.iloc[np.r_[1, 10, 20, 40,60,80,100,120,140,160,180], 1:].T.values,showfliers= True,showmeans = True,autorange= True,capprops=capprops,boxprops = boxprops)

# print(df.iloc[np.r_[1, 10, 20, 40,60,80,100,120,140,160,180]])
x_labels = [str(x) for x in [1, 10, 20, 40,60,80,100,120,140,160,180]]

# 设置x轴刻度标签
ax1.set_xticklabels(x_labels)
ax1.legend().remove()
# 设置图表标题和坐标轴标签
ax1.set_ylabel("ENERGY SCORE",size=17)
ax1.set_xlabel("EPOCHS",size=17)
ax1.set_title("IND",fontsize=17)


df = pd.read_csv('./GNNSafe/results/myresults/detect_ind_maxmin_energy_score.csv')
ax2 = df.iloc[:,0].plot(title="IND",ax=ax2,grid=False,color='#F40D43',linewidth=2)
ax2.set_ylabel("ENERGY SCORE",size=17)
ax2.set_xlabel("EPOCHS",size=17)
ax2.set_title("IND",fontsize=17)
ax2.legend().remove()
ax2.legend(bbox_to_anchor=(0.5, -0.65),loc='lower center',ncol=3,fontsize=13)
sns.set(style='white')


df = pd.read_csv('./GNNSafe/results/myresults/detect_ind_maxmin_energy_score.csv')
ax3 = df.iloc[:,1].plot(title="IND",ax=ax3,grid=False,color='#66C2A5',linewidth=2)
ax3.set_ylabel("ENERGY SCORE",size=17)
ax3.set_xlabel("EPOCHS",size=17)
ax3.set_title("IND",fontsize=17)
ax3.legend().remove()
ax3.legend(bbox_to_anchor=(0.5, -0.65),loc='lower center',ncol=3,fontsize=13)
sns.set(style='white')

##################################################################################

df = pd.read_csv('./GNNSafe/results/myresults/detect_In_Out_max_min.csv')
# patch_artist=True
# boxprops = {'color': 'blue','facecolor':'b'}
boxprops = {'color': 'BLUE'}
capprops = {'color': 'red', 'linewidth': '1.5'}
# 绘制每一行数据的箱线图
# np.r_[1:3, 15, 17, 50:52] 指定行数
ax4.boxplot(df.iloc[np.r_[1, 10, 20, 40,60,80,100,120,140,160,180], 1:].T.values,showfliers= True,showmeans = True,autorange= True,capprops=capprops,boxprops = boxprops)
x_labels = [str(x) for x in [1, 10, 20, 40,60,80,100,120,140,160,180]]

# 设置x轴刻度标签
ax4.set_xticklabels(x_labels)
ax4.legend().remove()
# 设置图表标题和坐标轴标签
ax4.set_ylabel("ENERGY SCORE",size=17)
ax4.set_xlabel("EPOCHS",size=17)
ax4.set_title("OOD",fontsize=17)


df = pd.read_csv('./GNNSafe/results/myresults/detect_ood_maxmin_energy_score.csv')
ax5 = df.iloc[:,2].plot(title="IND",ax=ax5,grid=False,color='#F40D43',linewidth=2)
ax5.set_ylabel("ENERGY SCORE",size=17)
ax5.set_xlabel("EPOCHS",size=17)
ax5.set_title("OOD",fontsize=17)
ax5.legend().remove()
# ax5.legend(bbox_to_anchor=(0.5, -0.65),loc='lower center',ncol=3,fontsize=13)
sns.set(style='white')


df = pd.read_csv('./GNNSafe/results/myresults/detect_ood_maxmin_energy_score.csv')
ax6 = df.iloc[:,3].plot(title="IND",ax=ax6,grid=False,color='#66C2A5',linewidth=2)
ax6.set_ylabel("ENERGY SCORE",size=17)
ax6.set_xlabel("EPOCHS",size=17)
ax6.set_title("OOD",fontsize=17)
# ax6.legend(bbox_to_anchor=(0.5, -0.65),loc='lower center',ncol=3,fontsize=13)
sns.set(style='white')
ax6.legend().remove()

fig.savefig('./figs/111.pdf', bbox_inches='tight')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

data_ind = pd.read_csv('./GNNSafe/results/myresults/Out_max_min.csv')
data_ood = pd.read_csv('./GNNSafe/results/myresults/In_max_min.csv')

# avrage_data = pd.read_csv('./GNNSafe/results/maxmin_mytest2.csv')

# 设置颜色代码
color1 = "#038355" # 孔雀绿
color2 = "#ffc34e" # 向日黄

fig = plt.figure(figsize=(18,8),dpi=100)
plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=None, hspace=0.4)#调整子图间距

axes = fig.subplots(nrows=2, ncols=1)
ax1, ax2 = axes.ravel()
ax1.tick_params(labelsize=15)
ax2.tick_params(labelsize=15)

ax = data_ind.iloc[:,[0,-1]].plot.area(title="IND",ax=ax1,grid=False,linewidth=2.5,stacked=False)
ax.set_title("IND",fontsize=17)
ax.set_xlabel("EPOCHS",size=17)
ax.set_ylabel("ENERGY SCORE",size=17)

ax = data_ood.iloc[:,[0,-1]].plot.area(title="IND",ax=ax1,grid=False,linewidth=2.5,stacked=False)
ax.set_title("IND",fontsize=17)
ax.set_xlabel("EPOCHS",size=17)
ax.set_ylabel("ENERGY SCORE",size=17)

# ax = avrage_data.plot.area(title="avrage_data",ax=ax2,grid=False,stacked=False,linewidth=1)
# ax.legend(loc='lower right',ncol=2,fontsize=13,)
# ax.set_ylabel("ENERGY SCORE",size=17)
# ax.set_xlabel("EPOCHS",size=17)
# ax.set_title("IND_OOD_SCORE_MAX_MIN",fontsize=17)

# %%
import pandas as pd
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(18,8),dpi=100)
plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=0.3, hspace=0.4)#调整子图间距

axes = fig.subplots(nrows=2, ncols=3)
ax1, ax2,ax3, ax4,ax5, ax6 = axes.ravel()


df = pd.read_csv('./GNNSafe/results/myresults/detect_ind_maxmin_energy_score.csv')
# patch_artist=True
# boxprops = {'color': 'blue','facecolor':'b'}
boxprops = {'color': 'blue'}

capprops = {'color': 'red', 'linewidth': '1.5'}
# 创建一个包含每一行为箱线图数据的DataFrame
# df = pd.DataFrame({
#     'Min': [0, 2, 3, 4, 1,1],
#     'Q1': [12, 14, 16, 18, 100,12],
#     'Median': [24, 26, 28, 30, 32,23],
#     'Q3': [36, 38, 40, 42, 44,123],
#     'Max': [48, 50, 52, 54, 56,55]
# })
# print(df.T.shape)
# 绘制每一行数据的箱线图
# np.r_[1:3, 15, 17, 50:52] 指定行数
ax1.boxplot(df.iloc[np.r_[1, 10, 20, 40,60,80,100,120,140,160,180], 1:].T.values,showfliers= False,showmeans = True,autorange= True,capprops=capprops,boxprops = boxprops)

# print(df.iloc[np.r_[1, 10, 20, 40,60,80,100,120,140,160,180]])
x_labels = [str(x) for x in [1, 10, 20, 40,60,80,100,120,140,160,180]]

# 设置x轴刻度标签
ax1.set_xticklabels(x_labels)
ax1.legend().remove()
# 设置图表标题和坐标轴标签
ax1.set_ylabel("ENERGY SCORE",size=17)
ax1.set_xlabel("EPOCHS",size=17)
ax1.set_title("IND",fontsize=17)


df = pd.read_csv('./GNNSafe/results/myresults/detect_In_Out_max_min.csv')
ax2 = df.iloc[:,0].plot(title="IND",ax=ax2,grid=False,color='#F40D43',linewidth=2)
ax2.set_ylabel("ENERGY SCORE",size=17)
ax2.set_xlabel("EPOCHS",size=17)
ax2.set_title("IND",fontsize=17)
ax2.legend().remove()
ax2.legend(bbox_to_anchor=(0.5, -0.65),loc='lower center',ncol=3,fontsize=13)
sns.set(style='white')


df = pd.read_csv('./GNNSafe/results/myresults/detect_In_Out_max_min.csv')
ax3 = df.iloc[:,1].plot(title="IND",ax=ax3,grid=False,color='#66C2A5',linewidth=2)
ax3.set_ylabel("ENERGY SCORE",size=17)
ax3.set_xlabel("EPOCHS",size=17)
ax3.set_title("IND",fontsize=17)
ax3.legend().remove()
ax3.legend(bbox_to_anchor=(0.5, -0.65),loc='lower center',ncol=3,fontsize=13)
sns.set(style='white')

##################################################################################

df = pd.read_csv('./GNNSafe/results/myresults/detect_ood_maxmin_energy_score.csv')
# patch_artist=True
# boxprops = {'color': 'blue','facecolor':'b'}
boxprops = {'color': 'BLUE'}
capprops = {'color': 'red', 'linewidth': '1.5'}
# 绘制每一行数据的箱线图
# np.r_[1:3, 15, 17, 50:52] 指定行数
ax4.boxplot(df.iloc[np.r_[1, 10, 20, 40,60,80,100,120,140,160,180], 1:].T.values,showfliers= False,showmeans = True,autorange= True,capprops=capprops,boxprops = boxprops)
x_labels = [str(x) for x in [1, 10, 20, 40,60,80,100,120,140,160,180]]

# 设置x轴刻度标签
ax4.set_xticklabels(x_labels)
ax4.legend().remove()
# 设置图表标题和坐标轴标签
ax4.set_ylabel("ENERGY SCORE",size=17)
ax4.set_xlabel("EPOCHS",size=17)
ax4.set_title("IND",fontsize=17)


df = pd.read_csv('./GNNSafe/results/myresults/detect_In_Out_max_min.csv')
ax5 = df.iloc[:,2].plot(title="IND",ax=ax5,grid=False,color='#F40D43',linewidth=2)
ax5.set_ylabel("ENERGY SCORE",size=17)
ax5.set_xlabel("EPOCHS",size=17)
ax5.set_title("IND",fontsize=17)
ax5.legend().remove()
# ax5.legend(bbox_to_anchor=(0.5, -0.65),loc='lower center',ncol=3,fontsize=13)
sns.set(style='white')


df = pd.read_csv('./GNNSafe/results/myresults/detect_In_Out_max_min.csv')
ax6 = df.iloc[:,3].plot(title="IND",ax=ax6,grid=False,color='#66C2A5',linewidth=2)
ax6.set_ylabel("ENERGY SCORE",size=17)
ax6.set_xlabel("EPOCHS",size=17)
ax6.set_title("IND",fontsize=17)
# ax6.legend(bbox_to_anchor=(0.5, -0.65),loc='lower center',ncol=3,fontsize=13)
sns.set(style='white')
ax6.legend().remove()

fig.savefig('./figs/after_arviv-score.pdf', bbox_inches='tight')

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('./GNNSafe/results/myresults/In_max_min.csv')
print(data.shape)
# patch_artist=True
# boxprops = {'color': 'blue','facecolor':'b'}
boxprops = {'color': 'blue'}

capprops = {'color': 'red', 'linewidth': '1.5'}
# 创建一个包含每一行为箱线图数据的DataFrame
# df = pd.DataFrame({
#     'Min': [0, 2, 3, 4, 1,1],
#     'Q1': [12, 14, 16, 18, 100,12],
#     'Median': [24, 26, 28, 30, 32,23],
#     'Q3': [36, 38, 40, 42, 44,123],
#     'Max': [48, 50, 52, 54, 56,55]
# })
# print(df.T.shape)
# 绘制每一行数据的箱线图
# np.r_[1:3, 15, 17, 50:52] 指定行数
plt.boxplot(df.iloc[np.r_[1, 10, 20, 40,60,80,100,120,140,160,180], 1:].T.values,showfliers= True,showmeans = True,autorange= True,capprops=capprops,boxprops = boxprops)

print(df.iloc[np.r_[1, 10, 20, 40,60,80,100,120,140,160,180]])
x_labels = [str(x) for x in [1, 10, 20, 40,60,80,100,120,140,160,180]]

# 设置x轴刻度标签
plt.xticks(range(1, len([1, 10, 20, 40,60,80,100,120,140,160,180]) + 1), x_labels)

# 设置图表标题和坐标轴标签
plt.title('Boxplot Example')
plt.xlabel('Data')
plt.ylabel('Values')

# 显示图表
plt.show()
